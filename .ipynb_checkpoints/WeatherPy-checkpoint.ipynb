# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
import math

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 628

# %%
city_df = pd.DataFrame(cities)
city_df = city_df.rename(columns={0:"City"})

city_df['Cloudiness'] = ""
city_df['Country'] = ""
city_df['Date'] = ""
city_df['Humidity'] = ""
city_df['Lat'] = ""
city_df['Lng'] = ""
city_df['Max Temp'] = ""
city_df['Wind Speed'] = ""

# city_df.head(8)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
limit = len(city_df)/50
set_var = 1
data_count = 50
dummy_array = [];


base_url = "http://api.openweathermap.org/data/2.5/weather?"
params = {'appid': api_key, 'units': 'Imperial'}

for index, row in city_df.iterrows():
    if len(dummy_array) < data_count and set_var <= math.ceil(limit):
        city_row = row['City']
        dummy_array.append(city_row)
       
        params['q'] = city_row

        response = requests.get(base_url, params=params).json()
    
    else:
        set_var = set_var + 1
        data_count = data_count + 49
        time.sleep(60)

    
    try:
        pprint(f"Processing Record for index #{index + 1} / set {set_var}: {city_row}")

        city_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        city_df.loc[index, 'Country'] = response['sys']['country']
        city_df.loc[index, 'Date'] = response['main']['temp_max']
        city_df.loc[index, 'Humidity'] = response['main']['humidity']
        city_df.loc[index, 'Lat'] = response['coord']['lat']
        city_df.loc[index, 'Lng'] = response['coord']['lon']
        city_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        
    except (KeyError, IndexError):
        pprint("Missing field/result... skipping.")
        
    print("------------")
# Out:
# 'Processing Record for index #1 / set 1: puri'
# ------------
# 'Processing Record for index #2 / set 1: guadalupe y calvo'
# ------------
# 'Processing Record for index #3 / set 1: rikitea'
# ------------
# 'Processing Record for index #4 / set 1: barentsburg'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #5 / set 1: saldanha'
# ------------
# 'Processing Record for index #6 / set 1: port hardy'
# ------------
# 'Processing Record for index #7 / set 1: mehamn'
# ------------
# 'Processing Record for index #8 / set 1: khatanga'
# ------------
# 'Processing Record for index #9 / set 1: bambous virieux'
# ------------
# 'Processing Record for index #10 / set 1: port elizabeth'
# ------------
# 'Processing Record for index #11 / set 1: port macquarie'
# ------------
# 'Processing Record for index #12 / set 1: georgetown'
# ------------
# 'Processing Record for index #13 / set 1: jackson'
# ------------
# 'Processing Record for index #14 / set 1: haileybury'
# ------------
# 'Processing Record for index #15 / set 1: puerto ayora'
# ------------
# 'Processing Record for index #16 / set 1: bengkulu'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #17 / set 1: cape town'
# ------------
# 'Processing Record for index #18 / set 1: vardo'
# ------------
# 'Processing Record for index #19 / set 1: tsihombe'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #20 / set 1: vaini'
# ------------
# 'Processing Record for index #21 / set 1: talaya'
# ------------
# 'Processing Record for index #22 / set 1: bowen'
# ------------
# 'Processing Record for index #23 / set 1: urengoy'
# ------------
# 'Processing Record for index #24 / set 1: mahebourg'
# ------------
# 'Processing Record for index #25 / set 1: karratha'
# ------------
# 'Processing Record for index #26 / set 1: san quintin'
# ------------
# 'Processing Record for index #27 / set 1: sao joao da barra'
# ------------
# 'Processing Record for index #28 / set 1: sioux lookout'
# ------------
# 'Processing Record for index #29 / set 1: tasiilaq'
# ------------
# 'Processing Record for index #30 / set 1: bargal'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #31 / set 1: saint george'
# ------------
# 'Processing Record for index #32 / set 1: sokolskoye'
# ------------
# 'Processing Record for index #33 / set 1: warmbad'
# ------------
# 'Processing Record for index #34 / set 1: lhokseumawe'
# ------------
# 'Processing Record for index #35 / set 1: tuy hoa'
# ------------
# 'Processing Record for index #36 / set 1: santa cruz del sur'
# ------------
# 'Processing Record for index #37 / set 1: ushuaia'
# ------------
# 'Processing Record for index #38 / set 1: pskov'
# ------------
# 'Processing Record for index #39 / set 1: kapaa'
# ------------
# 'Processing Record for index #40 / set 1: mar del plata'
# ------------
# 'Processing Record for index #41 / set 1: albany'
# ------------
# 'Processing Record for index #42 / set 1: maravilha'
# ------------
# 'Processing Record for index #43 / set 1: jamestown'
# ------------
# 'Processing Record for index #44 / set 1: katherine'
# ------------
# 'Processing Record for index #45 / set 1: khilok'
# ------------
# 'Processing Record for index #46 / set 1: punta arenas'
# ------------
# 'Processing Record for index #47 / set 1: burica'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #48 / set 1: najran'
# ------------
# 'Processing Record for index #49 / set 1: belushya guba'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #50 / set 1: victoria'
# ------------
# 'Processing Record for index #51 / set 2: victoria'
# ------------
# 'Processing Record for index #52 / set 2: new norfolk'
# ------------
# 'Processing Record for index #53 / set 2: taolanaro'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #54 / set 2: lasa'
# ------------
# 'Processing Record for index #55 / set 2: leningradskiy'
# ------------
# 'Processing Record for index #56 / set 2: sao filipe'
# ------------
# 'Processing Record for index #57 / set 2: alice springs'
# ------------
# 'Processing Record for index #58 / set 2: barrow'
# ------------
# 'Processing Record for index #59 / set 2: vancouver'
# ------------
# 'Processing Record for index #60 / set 2: hatta'
# ------------
# 'Processing Record for index #61 / set 2: narsaq'
# ------------
# 'Processing Record for index #62 / set 2: kaitangata'
# ------------
# 'Processing Record for index #63 / set 2: klaksvik'
# ------------
# 'Processing Record for index #64 / set 2: bluff'
# ------------
# 'Processing Record for index #65 / set 2: airai'
# ------------
# 'Processing Record for index #66 / set 2: bilma'
# ------------
# 'Processing Record for index #67 / set 2: bredasdorp'
# ------------
# 'Processing Record for index #68 / set 2: illoqqortoormiut'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #69 / set 2: biltine'
# ------------
# 'Processing Record for index #70 / set 2: constantine'
# ------------
# 'Processing Record for index #71 / set 2: san patricio'
# ------------
# 'Processing Record for index #72 / set 2: atuona'
# ------------
# 'Processing Record for index #73 / set 2: grand river south east'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #74 / set 2: tiksi'
# ------------
# 'Processing Record for index #75 / set 2: whitehorse'
# ------------
# 'Processing Record for index #76 / set 2: saint-philippe'
# ------------
# 'Processing Record for index #77 / set 2: kem'
# ------------
# 'Processing Record for index #78 / set 2: severo-kurilsk'
# ------------
# 'Processing Record for index #79 / set 2: cariamanga'
# ------------
# 'Processing Record for index #80 / set 2: hermanus'
# ------------
# 'Processing Record for index #81 / set 2: great yarmouth'
# ------------
# 'Processing Record for index #82 / set 2: mirador'
# ------------
# 'Processing Record for index #83 / set 2: toyooka'
# ------------
# 'Processing Record for index #84 / set 2: andenes'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #85 / set 2: busselton'
# ------------
# 'Processing Record for index #86 / set 2: kruisfontein'
# ------------
# 'Processing Record for index #87 / set 2: castro-urdiales'
# ------------
# 'Processing Record for index #88 / set 2: sitka'
# ------------
# 'Processing Record for index #89 / set 2: victoria point'
# ------------
# 'Processing Record for index #90 / set 2: samusu'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #91 / set 2: gisborne'
# ------------
# 'Processing Record for index #92 / set 2: muravlenko'
# ------------
# 'Processing Record for index #93 / set 2: mugur-aksy'
# ------------
# 'Processing Record for index #94 / set 2: san vicente'
# ------------
# 'Processing Record for index #95 / set 2: tuktoyaktuk'
# ------------
# 'Processing Record for index #96 / set 2: natal'
# ------------
# 'Processing Record for index #97 / set 2: ilulissat'
# ------------
# 'Processing Record for index #98 / set 2: awjilah'
# ------------
# 'Processing Record for index #99 / set 2: hobart'
# ------------
# 'Processing Record for index #100 / set 2: isangel'
# ------------
# 'Processing Record for index #101 / set 3: isangel'
# ------------
# 'Processing Record for index #102 / set 3: provideniya'
# ------------
# 'Processing Record for index #103 / set 3: parati'
# ------------
# 'Processing Record for index #104 / set 3: salinopolis'
# ------------
# 'Processing Record for index #105 / set 3: bahawalnagar'
# ------------
# 'Processing Record for index #106 / set 3: cairns'
# ------------
# 'Processing Record for index #107 / set 3: koster'
# ------------
# 'Processing Record for index #108 / set 3: beira'
# ------------
# 'Processing Record for index #109 / set 3: la seyne-sur-mer'
# ------------
# 'Processing Record for index #110 / set 3: daman'
# ------------
# 'Processing Record for index #111 / set 3: mataura'
# ------------
# 'Processing Record for index #112 / set 3: aksu'
# ------------
# 'Processing Record for index #113 / set 3: szydlowiec'
# ------------
# 'Processing Record for index #114 / set 3: wairoa'
# ------------
# 'Processing Record for index #115 / set 3: comodoro rivadavia'
# ------------
# 'Processing Record for index #116 / set 3: san juan'
# ------------
# 'Processing Record for index #117 / set 3: touros'
# ------------
# 'Processing Record for index #118 / set 3: vestmanna'
# ------------
# 'Processing Record for index #119 / set 3: lazaro cardenas'
# ------------
# 'Processing Record for index #120 / set 3: ribeira grande'
# ------------
# 'Processing Record for index #121 / set 3: vesyegonsk'
# ------------
# 'Processing Record for index #122 / set 3: clyde river'
# ------------
# 'Processing Record for index #123 / set 3: cherskiy'
# ------------
# 'Processing Record for index #124 / set 3: satitoa'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #125 / set 3: nizhneyansk'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #126 / set 3: prince rupert'
# ------------
# 'Processing Record for index #127 / set 3: arraial do cabo'
# ------------
# 'Processing Record for index #128 / set 3: broken hill'
# ------------
# 'Processing Record for index #129 / set 3: hilo'
# ------------
# 'Processing Record for index #130 / set 3: dicabisagan'
# ------------
# 'Processing Record for index #131 / set 3: mackay'
# ------------
# 'Processing Record for index #132 / set 3: torbay'
# ------------
# 'Processing Record for index #133 / set 3: fortuna'
# ------------
# 'Processing Record for index #134 / set 3: pevek'
# ------------
# 'Processing Record for index #135 / set 3: ponta do sol'
# ------------
# 'Processing Record for index #136 / set 3: ishigaki'
# ------------
# 'Processing Record for index #137 / set 3: nguiu'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #138 / set 3: sorvag'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #139 / set 3: baghdad'
# ------------
# 'Processing Record for index #140 / set 3: cabo san lucas'
# ------------
# 'Processing Record for index #141 / set 3: mys shmidta'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #142 / set 3: burns lake'
# ------------
# 'Processing Record for index #143 / set 3: amderma'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #144 / set 3: jutiapa'
# ------------
# 'Processing Record for index #145 / set 3: isla mujeres'
# ------------
# 'Processing Record for index #146 / set 3: oistins'
# ------------
# 'Processing Record for index #147 / set 3: lebu'
# ------------
# 'Processing Record for index #148 / set 3: lubyany'
# ------------
# 'Processing Record for index #149 / set 3: kjopsvik'
# ------------
# 'Processing Record for index #150 / set 3: simpang'
# ------------
# 'Processing Record for index #151 / set 4: simpang'
# ------------
# 'Processing Record for index #152 / set 4: avarua'
# ------------
# 'Processing Record for index #153 / set 4: west fargo'
# ------------
# 'Processing Record for index #154 / set 4: valle de allende'
# ------------
# 'Processing Record for index #155 / set 4: lolua'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #156 / set 4: japura'
# ------------
# 'Processing Record for index #157 / set 4: ozernovskiy'
# ------------
# 'Processing Record for index #158 / set 4: marzuq'
# ------------
# 'Processing Record for index #159 / set 4: edd'
# ------------
# 'Processing Record for index #160 / set 4: tessalit'
# ------------
# 'Processing Record for index #161 / set 4: nikolskoye'
# ------------
# 'Processing Record for index #162 / set 4: santa cruz'
# ------------
# 'Processing Record for index #163 / set 4: nouadhibou'
# ------------
# 'Processing Record for index #164 / set 4: wagar'
# ------------
# 'Processing Record for index #165 / set 4: east london'
# ------------
# 'Processing Record for index #166 / set 4: mashhad'
# ------------
# 'Processing Record for index #167 / set 4: port lincoln'
# ------------
# 'Processing Record for index #168 / set 4: astoria'
# ------------
# 'Processing Record for index #169 / set 4: marcona'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #170 / set 4: san miguel'
# ------------
# 'Processing Record for index #171 / set 4: tura'
# ------------
# 'Processing Record for index #172 / set 4: samarai'
# ------------
# 'Processing Record for index #173 / set 4: beloha'
# ------------
# 'Processing Record for index #174 / set 4: carnarvon'
# ------------
# 'Processing Record for index #175 / set 4: tiznit'
# ------------
# 'Processing Record for index #176 / set 4: vila do maio'
# ------------
# 'Processing Record for index #177 / set 4: isagarh'
# ------------
# 'Processing Record for index #178 / set 4: poum'
# ------------
# 'Processing Record for index #179 / set 4: mogok'
# ------------
# 'Processing Record for index #180 / set 4: tagusao'
# ------------
# 'Processing Record for index #181 / set 4: gulariya'
# ------------
# 'Processing Record for index #182 / set 4: nemuro'
# ------------
# 'Processing Record for index #183 / set 4: saint-joseph'
# ------------
# 'Processing Record for index #184 / set 4: college'
# ------------
# 'Processing Record for index #185 / set 4: balimo'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #186 / set 4: thompson'
# ------------
# 'Processing Record for index #187 / set 4: arica'
# ------------
# 'Processing Record for index #188 / set 4: san cristobal'
# ------------
# 'Processing Record for index #189 / set 4: kodiak'
# ------------
# 'Processing Record for index #190 / set 4: faanui'
# ------------
# 'Processing Record for index #191 / set 4: thinadhoo'
# ------------
# 'Processing Record for index #192 / set 4: mildura'
# ------------
# 'Processing Record for index #193 / set 4: qasigiannguit'
# ------------
# 'Processing Record for index #194 / set 4: turukhansk'
# ------------
# 'Processing Record for index #195 / set 4: goderich'
# ------------
# 'Processing Record for index #196 / set 4: chuy'
# ------------
# 'Processing Record for index #197 / set 4: tabiauea'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #198 / set 4: padang'
# ------------
# 'Processing Record for index #199 / set 4: sentyabrskiy'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #200 / set 4: grand centre'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #201 / set 5: grand centre'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #202 / set 5: egvekinot'
# ------------
# 'Processing Record for index #203 / set 5: trois-rivieres'
# ------------
# 'Processing Record for index #204 / set 5: bolungarvik'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #205 / set 5: lagoa'
# ------------
# 'Processing Record for index #206 / set 5: severo-yeniseyskiy'
# ------------
# 'Processing Record for index #207 / set 5: okha'
# ------------
# 'Processing Record for index #208 / set 5: kiama'
# ------------
# 'Processing Record for index #209 / set 5: havelock'
# ------------
# 'Processing Record for index #210 / set 5: bendigo'
# ------------
# 'Processing Record for index #211 / set 5: beroroha'
# ------------
# 'Processing Record for index #212 / set 5: longyearbyen'
# ------------
# 'Processing Record for index #213 / set 5: cheremukhovo'
# ------------
# 'Processing Record for index #214 / set 5: port alfred'
# ------------
# 'Processing Record for index #215 / set 5: porto santo'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #216 / set 5: deputatskiy'
# ------------
# 'Processing Record for index #217 / set 5: beisfjord'
# ------------
# 'Processing Record for index #218 / set 5: esperance'
# ------------
# 'Processing Record for index #219 / set 5: kosino'
# ------------
# 'Processing Record for index #220 / set 5: yeppoon'
# ------------
# 'Processing Record for index #221 / set 5: mazagao'
# ------------
# 'Processing Record for index #222 / set 5: majene'
# ------------
# 'Processing Record for index #223 / set 5: karachi'
# ------------
# 'Processing Record for index #224 / set 5: weinan'
# ------------
# 'Processing Record for index #225 / set 5: yugorsk'
# ------------
# 'Processing Record for index #226 / set 5: yellowknife'
# ------------
# 'Processing Record for index #227 / set 5: celendin'
# ------------
# 'Processing Record for index #228 / set 5: sao jose da coroa grande'
# ------------
# 'Processing Record for index #229 / set 5: jaora'
# ------------
# 'Processing Record for index #230 / set 5: muisne'
# ------------
# 'Processing Record for index #231 / set 5: pangnirtung'
# ------------
# 'Processing Record for index #232 / set 5: hokitika'
# ------------
# 'Processing Record for index #233 / set 5: rabo de peixe'
# ------------
# 'Processing Record for index #234 / set 5: vaitupu'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #235 / set 5: naze'
# ------------
# 'Processing Record for index #236 / set 5: hambantota'
# ------------
# 'Processing Record for index #237 / set 5: spring valley'
# ------------
# 'Processing Record for index #238 / set 5: chokurdakh'
# ------------
# 'Processing Record for index #239 / set 5: lata'
# ------------
# 'Processing Record for index #240 / set 5: avera'
# ------------
# 'Processing Record for index #241 / set 5: larsnes'
# ------------
# 'Processing Record for index #242 / set 5: merauke'
# ------------
# 'Processing Record for index #243 / set 5: tubruq'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #244 / set 5: barcelona'
# ------------
# 'Processing Record for index #245 / set 5: mayo'
# ------------
# 'Processing Record for index #246 / set 5: barranca'
# ------------
# 'Processing Record for index #247 / set 5: nome'
# ------------
# 'Processing Record for index #248 / set 5: faya'
# ------------
# 'Processing Record for index #249 / set 5: aripuana'
# ------------
# 'Processing Record for index #250 / set 5: uporovo'
# ------------
# 'Processing Record for index #251 / set 6: uporovo'
# ------------
# 'Processing Record for index #252 / set 6: hualmay'
# ------------
# 'Processing Record for index #253 / set 6: scottsburgh'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #254 / set 6: pisco'
# ------------
# 'Processing Record for index #255 / set 6: ahuimanu'
# ------------
# 'Processing Record for index #256 / set 6: ambunti'
# ------------
# 'Processing Record for index #257 / set 6: veraval'
# ------------
# 'Processing Record for index #258 / set 6: nybro'
# ------------
# 'Processing Record for index #259 / set 6: talnakh'
# ------------
# 'Processing Record for index #260 / set 6: cidreira'
# ------------
# 'Processing Record for index #261 / set 6: kavaratti'
# ------------
# 'Processing Record for index #262 / set 6: magadan'
# ------------
# 'Processing Record for index #263 / set 6: ciudad bolivar'
# ------------
# 'Processing Record for index #264 / set 6: berlevag'
# ------------
# 'Processing Record for index #265 / set 6: qaanaaq'
# ------------
# 'Processing Record for index #266 / set 6: batagay-alyta'
# ------------
# 'Processing Record for index #267 / set 6: chumikan'
# ------------
# 'Processing Record for index #268 / set 6: falealupo'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #269 / set 6: banda aceh'
# ------------
# 'Processing Record for index #270 / set 6: nenjiang'
# ------------
# 'Processing Record for index #271 / set 6: ternate'
# ------------
# 'Processing Record for index #272 / set 6: sangar'
# ------------
# 'Processing Record for index #273 / set 6: chipinge'
# ------------
# 'Processing Record for index #274 / set 6: kavieng'
# ------------
# 'Processing Record for index #275 / set 6: bitung'
# ------------
# 'Processing Record for index #276 / set 6: santa rosa'
# ------------
# 'Processing Record for index #277 / set 6: jacareacanga'
# ------------
# 'Processing Record for index #278 / set 6: axim'
# ------------
# 'Processing Record for index #279 / set 6: kahului'
# ------------
# 'Processing Record for index #280 / set 6: fernley'
# ------------
# 'Processing Record for index #281 / set 6: velyka mykhaylivka'
# ------------
# 'Processing Record for index #282 / set 6: pulandian'
# ------------
# 'Processing Record for index #283 / set 6: san andres'
# ------------
# 'Processing Record for index #284 / set 6: luganville'
# ------------
# 'Processing Record for index #285 / set 6: gillette'
# ------------
# 'Processing Record for index #286 / set 6: sucua'
# ------------
# 'Processing Record for index #287 / set 6: kudahuvadhoo'
# ------------
# 'Processing Record for index #288 / set 6: nola'
# ------------
# 'Processing Record for index #289 / set 6: paita'
# ------------
# 'Processing Record for index #290 / set 6: garowe'
# ------------
# 'Processing Record for index #291 / set 6: port blair'
# ------------
# 'Processing Record for index #292 / set 6: itoman'
# ------------
# 'Processing Record for index #293 / set 6: butaritari'
# ------------
# 'Processing Record for index #294 / set 6: dunedin'
# ------------
# 'Processing Record for index #295 / set 6: te anau'
# ------------
# 'Processing Record for index #296 / set 6: codajas'
# ------------
# 'Processing Record for index #297 / set 6: alofi'
# ------------
# 'Processing Record for index #298 / set 6: ayan'
# ------------
# 'Processing Record for index #299 / set 6: halifax'
# ------------
# 'Processing Record for index #300 / set 6: srednekolymsk'
# ------------
# 'Processing Record for index #301 / set 7: srednekolymsk'
# ------------
# 'Processing Record for index #302 / set 7: dongsheng'
# ------------
# 'Processing Record for index #303 / set 7: tarko-sale'
# ------------
# 'Processing Record for index #304 / set 7: nanortalik'
# ------------
# 'Processing Record for index #305 / set 7: atasu'
# ------------
# 'Processing Record for index #306 / set 7: launceston'
# ------------
# 'Processing Record for index #307 / set 7: morehead'
# ------------
# 'Processing Record for index #308 / set 7: sandakan'
# ------------
# 'Processing Record for index #309 / set 7: baker city'
# ------------
# 'Processing Record for index #310 / set 7: ahipara'
# ------------
# 'Processing Record for index #311 / set 7: poronaysk'
# ------------
# 'Processing Record for index #312 / set 7: wanaka'
# ------------
# 'Processing Record for index #313 / set 7: codrington'
# ------------
# 'Processing Record for index #314 / set 7: amalapuram'
# ------------
# 'Processing Record for index #315 / set 7: harlingen'
# ------------
# 'Processing Record for index #316 / set 7: tiarei'
# ------------
# 'Processing Record for index #317 / set 7: ouricuri'
# ------------
# 'Processing Record for index #318 / set 7: toliary'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #319 / set 7: moron'
# ------------
# 'Processing Record for index #320 / set 7: dingle'
# ------------
# 'Processing Record for index #321 / set 7: lorengau'
# ------------
# 'Processing Record for index #322 / set 7: nacala'
# ------------
# 'Processing Record for index #323 / set 7: golcuv jenikov'
# ------------
# 'Processing Record for index #324 / set 7: umm bab'
# ------------
# 'Processing Record for index #325 / set 7: paralia'
# ------------
# 'Processing Record for index #326 / set 7: tsaratanana'
# ------------
# 'Processing Record for index #327 / set 7: bagli'
# ------------
# 'Processing Record for index #328 / set 7: mao'
# ------------
# 'Processing Record for index #329 / set 7: zolotinka'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #330 / set 7: labuhan'
# ------------
# 'Processing Record for index #331 / set 7: conakry'
# ------------
# 'Processing Record for index #332 / set 7: la ronge'
# ------------
# 'Processing Record for index #333 / set 7: flinders'
# ------------
# 'Processing Record for index #334 / set 7: rio gallegos'
# ------------
# 'Processing Record for index #335 / set 7: portland'
# ------------
# 'Processing Record for index #336 / set 7: bethel'
# ------------
# 'Processing Record for index #337 / set 7: beni'
# ------------
# 'Processing Record for index #338 / set 7: linhares'
# ------------
# 'Processing Record for index #339 / set 7: matara'
# ------------
# 'Processing Record for index #340 / set 7: umzimvubu'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #341 / set 7: skibbereen'
# ------------
# 'Processing Record for index #342 / set 7: oranjemund'
# ------------
# 'Processing Record for index #343 / set 7: upernavik'
# ------------
# 'Processing Record for index #344 / set 7: jijiga'
# ------------
# 'Processing Record for index #345 / set 7: yar-sale'
# ------------
# 'Processing Record for index #346 / set 7: salalah'
# ------------
# 'Processing Record for index #347 / set 7: brookhaven'
# ------------
# 'Processing Record for index #348 / set 7: ambodifototra'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #349 / set 7: dharchula'
# ------------
# 'Processing Record for index #350 / set 7: paraguari'
# ------------
# 'Processing Record for index #351 / set 8: paraguari'
# ------------
# 'Processing Record for index #352 / set 8: castro'
# ------------
# 'Processing Record for index #353 / set 8: riyadh'
# ------------
# 'Processing Record for index #354 / set 8: miri'
# ------------
# 'Processing Record for index #355 / set 8: ulychne'
# ------------
# 'Processing Record for index #356 / set 8: kamenskoye'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #357 / set 8: lieksa'
# ------------
# 'Processing Record for index #358 / set 8: puerto del rosario'
# ------------
# 'Processing Record for index #359 / set 8: havoysund'
# ------------
# 'Processing Record for index #360 / set 8: harper'
# ------------
# 'Processing Record for index #361 / set 8: namibe'
# ------------
# 'Processing Record for index #362 / set 8: saskylakh'
# ------------
# 'Processing Record for index #363 / set 8: port-cartier'
# ------------
# 'Processing Record for index #364 / set 8: tuatapere'
# ------------
# 'Processing Record for index #365 / set 8: galle'
# ------------
# 'Processing Record for index #366 / set 8: calatayud'
# ------------
# 'Processing Record for index #367 / set 8: vila franca do campo'
# ------------
# 'Processing Record for index #368 / set 8: canakkale'
# ------------
# 'Processing Record for index #369 / set 8: waipawa'
# ------------
# 'Processing Record for index #370 / set 8: timizart'
# ------------
# 'Processing Record for index #371 / set 8: amboasary'
# ------------
# 'Processing Record for index #372 / set 8: dikson'
# ------------
# 'Processing Record for index #373 / set 8: renukut'
# ------------
# 'Processing Record for index #374 / set 8: paamiut'
# ------------
# 'Processing Record for index #375 / set 8: ivanteyevka'
# ------------
# 'Processing Record for index #376 / set 8: grindavik'
# ------------
# 'Processing Record for index #377 / set 8: dukat'
# ------------
# 'Processing Record for index #378 / set 8: kristiansund'
# ------------
# 'Processing Record for index #379 / set 8: kasungu'
# ------------
# 'Processing Record for index #380 / set 8: north platte'
# ------------
# 'Processing Record for index #381 / set 8: hailey'
# ------------
# 'Processing Record for index #382 / set 8: hofn'
# ------------
# 'Processing Record for index #383 / set 8: saint-augustin'
# ------------
# 'Processing Record for index #384 / set 8: hare bay'
# ------------
# 'Processing Record for index #385 / set 8: moose factory'
# ------------
# 'Processing Record for index #386 / set 8: lao cai'
# ------------
# 'Processing Record for index #387 / set 8: husavik'
# ------------
# 'Processing Record for index #388 / set 8: bonthe'
# ------------
# 'Processing Record for index #389 / set 8: margate'
# ------------
# 'Processing Record for index #390 / set 8: pochutla'
# ------------
# 'Processing Record for index #391 / set 8: yumen'
# ------------
# 'Processing Record for index #392 / set 8: vao'
# ------------
# 'Processing Record for index #393 / set 8: alcains'
# ------------
# 'Processing Record for index #394 / set 8: sola'
# ------------
# 'Processing Record for index #395 / set 8: mount gambier'
# ------------
# 'Processing Record for index #396 / set 8: lodingen'
# ------------
# 'Processing Record for index #397 / set 8: altay'
# ------------
# 'Processing Record for index #398 / set 8: lavrentiya'
# ------------
# 'Processing Record for index #399 / set 8: itupiranga'
# ------------
# 'Processing Record for index #400 / set 8: ashland'
# ------------
# 'Processing Record for index #401 / set 9: ashland'
# ------------
# 'Processing Record for index #402 / set 9: turka'
# ------------
# 'Processing Record for index #403 / set 9: omboue'
# ------------
# 'Processing Record for index #404 / set 9: trat'
# ------------
# 'Processing Record for index #405 / set 9: bushehr'
# ------------
# 'Processing Record for index #406 / set 9: dubbo'
# ------------
# 'Processing Record for index #407 / set 9: buraydah'
# ------------
# 'Processing Record for index #408 / set 9: puerto escondido'
# ------------
# 'Processing Record for index #409 / set 9: rafai'
# ------------
# 'Processing Record for index #410 / set 9: roma'
# ------------
# 'Processing Record for index #411 / set 9: flagstaff'
# ------------
# 'Processing Record for index #412 / set 9: beringovskiy'
# ------------
# 'Processing Record for index #413 / set 9: balsas'
# ------------
# 'Processing Record for index #414 / set 9: mokolo'
# ------------
# 'Processing Record for index #415 / set 9: kerchevskiy'
# ------------
# 'Processing Record for index #416 / set 9: kaeo'
# ------------
# 'Processing Record for index #417 / set 9: huarmey'
# ------------
# 'Processing Record for index #418 / set 9: frisco'
# ------------
# 'Processing Record for index #419 / set 9: bathsheba'
# ------------
# 'Processing Record for index #420 / set 9: huambo'
# ------------
# 'Processing Record for index #421 / set 9: syamzha'
# ------------
# 'Processing Record for index #422 / set 9: lagos'
# ------------
# 'Processing Record for index #423 / set 9: bichis'
# ------------
# 'Processing Record for index #424 / set 9: alindao'
# ------------
# 'Processing Record for index #425 / set 9: nabire'
# ------------
# 'Processing Record for index #426 / set 9: jalu'
# ------------
# 'Processing Record for index #427 / set 9: gazni'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #428 / set 9: sorland'
# ------------
# 'Processing Record for index #429 / set 9: beipiao'
# ------------
# 'Processing Record for index #430 / set 9: real'
# ------------
# 'Processing Record for index #431 / set 9: owando'
# ------------
# 'Processing Record for index #432 / set 9: coleraine'
# ------------
# 'Processing Record for index #433 / set 9: mareeba'
# ------------
# 'Processing Record for index #434 / set 9: birao'
# ------------
# 'Processing Record for index #435 / set 9: henties bay'
# ------------
# 'Processing Record for index #436 / set 9: iqaluit'
# ------------
# 'Processing Record for index #437 / set 9: kidal'
# ------------
# 'Processing Record for index #438 / set 9: puerto madryn'
# ------------
# 'Processing Record for index #439 / set 9: coquimbo'
# ------------
# 'Processing Record for index #440 / set 9: ancud'
# ------------
# 'Processing Record for index #441 / set 9: fukue'
# ------------
# 'Processing Record for index #442 / set 9: tautira'
# ------------
# 'Processing Record for index #443 / set 9: solnechnyy'
# ------------
# 'Processing Record for index #444 / set 9: malwan'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #445 / set 9: cap malheureux'
# ------------
# 'Processing Record for index #446 / set 9: manaus'
# ------------
# 'Processing Record for index #447 / set 9: inuvik'
# ------------
# 'Processing Record for index #448 / set 9: inongo'
# ------------
# 'Processing Record for index #449 / set 9: chabahar'
# ------------
# 'Processing Record for index #450 / set 9: ulladulla'
# ------------
# 'Processing Record for index #451 / set 10: ulladulla'
# ------------
# 'Processing Record for index #452 / set 10: valparaiso'
# ------------
# 'Processing Record for index #453 / set 10: porto murtinho'
# ------------
# 'Processing Record for index #454 / set 10: isla aguada'
# ------------
# 'Processing Record for index #455 / set 10: malakal'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #456 / set 10: impfondo'
# ------------
# 'Processing Record for index #457 / set 10: warwick'
# ------------
# 'Processing Record for index #458 / set 10: lompoc'
# ------------
# 'Processing Record for index #459 / set 10: shieli'
# ------------
# 'Processing Record for index #460 / set 10: piacabucu'
# ------------
# 'Processing Record for index #461 / set 10: buluang'
# ------------
# 'Processing Record for index #462 / set 10: luancheng'
# ------------
# 'Processing Record for index #463 / set 10: pangai'
# ------------
# 'Processing Record for index #464 / set 10: aksay'
# ------------
# 'Processing Record for index #465 / set 10: grande prairie'
# ------------
# 'Processing Record for index #466 / set 10: bhimunipatnam'
# ------------
# 'Processing Record for index #467 / set 10: jiddah'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #468 / set 10: pitimbu'
# ------------
# 'Processing Record for index #469 / set 10: hasaki'
# ------------
# 'Processing Record for index #470 / set 10: wamba'
# ------------
# 'Processing Record for index #471 / set 10: bognor regis'
# ------------
# 'Processing Record for index #472 / set 10: mantua'
# ------------
# 'Processing Record for index #473 / set 10: laguna'
# ------------
# 'Processing Record for index #474 / set 10: key west'
# ------------
# 'Processing Record for index #475 / set 10: madison'
# ------------
# 'Processing Record for index #476 / set 10: orestias'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #477 / set 10: norman wells'
# ------------
# 'Processing Record for index #478 / set 10: miles city'
# ------------
# 'Processing Record for index #479 / set 10: brae'
# ------------
# 'Processing Record for index #480 / set 10: karamken'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #481 / set 10: okhotsk'
# ------------
# 'Processing Record for index #482 / set 10: sabha'
# ------------
# 'Processing Record for index #483 / set 10: buala'
# ------------
# 'Processing Record for index #484 / set 10: geraldton'
# ------------
# 'Processing Record for index #485 / set 10: mananjary'
# ------------
# 'Processing Record for index #486 / set 10: guder'
# ------------
# 'Processing Record for index #487 / set 10: margherita di savoia'
# ------------
# 'Processing Record for index #488 / set 10: alotau'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #489 / set 10: tecoanapa'
# ------------
# 'Processing Record for index #490 / set 10: muroto'
# ------------
# 'Processing Record for index #491 / set 10: bonavista'
# ------------
# 'Processing Record for index #492 / set 10: peniche'
# ------------
# 'Processing Record for index #493 / set 10: ballina'
# ------------
# 'Processing Record for index #494 / set 10: gazojak'
# ------------
# 'Processing Record for index #495 / set 10: cabedelo'
# ------------
# 'Processing Record for index #496 / set 10: tamandare'
# ------------
# 'Processing Record for index #497 / set 10: ostrovnoy'
# ------------
# 'Processing Record for index #498 / set 10: sibolga'
# ------------
# 'Processing Record for index #499 / set 10: nioro'
# ------------
# 'Processing Record for index #500 / set 10: quatre cocos'
# ------------
# 'Processing Record for index #501 / set 11: quatre cocos'
# ------------
# 'Processing Record for index #502 / set 11: souillac'
# ------------
# 'Processing Record for index #503 / set 11: zhangye'
# ------------
# 'Processing Record for index #504 / set 11: otane'
# ------------
# 'Processing Record for index #505 / set 11: panzhihua'
# ------------
# 'Processing Record for index #506 / set 11: gorontalo'
# ------------
# 'Processing Record for index #507 / set 11: zemio'
# ------------
# 'Processing Record for index #508 / set 11: elizabeth city'
# ------------
# 'Processing Record for index #509 / set 11: phitsanulok'
# ------------
# 'Processing Record for index #510 / set 11: caohai'
# ------------
# 'Processing Record for index #511 / set 11: santa comba'
# ------------
# 'Processing Record for index #512 / set 11: creston'
# ------------
# 'Processing Record for index #513 / set 11: kokkola'
# ------------
# 'Processing Record for index #514 / set 11: eydhafushi'
# ------------
# 'Processing Record for index #515 / set 11: boa vista'
# ------------
# 'Processing Record for index #516 / set 11: qaqortoq'
# ------------
# 'Processing Record for index #517 / set 11: cayenne'
# ------------
# 'Processing Record for index #518 / set 11: kapoeta'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #519 / set 11: pemangkat'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #520 / set 11: soria'
# ------------
# 'Processing Record for index #521 / set 11: la palma'
# ------------
# 'Processing Record for index #522 / set 11: mingshui'
# ------------
# 'Processing Record for index #523 / set 11: ijaki'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #524 / set 11: green river'
# ------------
# 'Processing Record for index #525 / set 11: belmonte'
# ------------
# 'Processing Record for index #526 / set 11: rungata'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #527 / set 11: laela'
# ------------
# 'Processing Record for index #528 / set 11: hamilton'
# ------------
# 'Processing Record for index #529 / set 11: la libertad'
# ------------
# 'Processing Record for index #530 / set 11: dong xoai'
# ------------
# 'Processing Record for index #531 / set 11: babra'
# ------------
# 'Processing Record for index #532 / set 11: kwale'
# ------------
# 'Processing Record for index #533 / set 11: fare'
# ------------
# 'Processing Record for index #534 / set 11: tabou'
# ------------
# 'Processing Record for index #535 / set 11: flin flon'
# ------------
# 'Processing Record for index #536 / set 11: tyret pervaya'
# ------------
# 'Processing Record for index #537 / set 11: saint-pierre'
# ------------
# 'Processing Record for index #538 / set 11: rocha'
# ------------
# 'Processing Record for index #539 / set 11: palencia'
# ------------
# 'Processing Record for index #540 / set 11: qinhuangdao'
# ------------
# 'Processing Record for index #541 / set 11: enumclaw'
# ------------
# 'Processing Record for index #542 / set 11: shimoda'
# ------------
# 'Processing Record for index #543 / set 11: athabasca'
# ------------
# 'Processing Record for index #544 / set 11: noumea'
# ------------
# 'Processing Record for index #545 / set 11: san carlos'
# ------------
# 'Processing Record for index #546 / set 11: saint-andre-avellin'
# ------------
# 'Processing Record for index #547 / set 11: koumac'
# ------------
# 'Processing Record for index #548 / set 11: jalesar'
# ------------
# 'Processing Record for index #549 / set 11: marinette'
# ------------
# 'Processing Record for index #550 / set 11: octeville'
# ------------
# 'Processing Record for index #551 / set 12: octeville'
# ------------
# 'Processing Record for index #552 / set 12: inirida'
# ------------
# 'Processing Record for index #553 / set 12: chegdomyn'
# ------------
# 'Processing Record for index #554 / set 12: penzance'
# ------------
# 'Processing Record for index #555 / set 12: kyzyl'
# ------------
# 'Processing Record for index #556 / set 12: honiara'
# ------------
# 'Processing Record for index #557 / set 12: half moon bay'
# ------------
# 'Processing Record for index #558 / set 12: katsuura'
# ------------
# 'Processing Record for index #559 / set 12: moba'
# ------------
# 'Processing Record for index #560 / set 12: high level'
# ------------
# 'Processing Record for index #561 / set 12: tres picos'
# ------------
# 'Processing Record for index #562 / set 12: byron bay'
# ------------
# 'Processing Record for index #563 / set 12: kuzino'
# ------------
# 'Processing Record for index #564 / set 12: antalaha'
# ------------
# 'Processing Record for index #565 / set 12: fairbanks'
# ------------
# 'Processing Record for index #566 / set 12: danjiangkou'
# ------------
# 'Processing Record for index #567 / set 12: dulce nombre de culmi'
# ------------
# 'Processing Record for index #568 / set 12: tommot'
# ------------
# 'Processing Record for index #569 / set 12: meulaboh'
# ------------
# 'Processing Record for index #570 / set 12: kralendijk'
# ------------
# 'Processing Record for index #571 / set 12: homer'
# ------------
# 'Processing Record for index #572 / set 12: angoche'
# ------------
# 'Processing Record for index #573 / set 12: yakeshi'
# ------------
# 'Processing Record for index #574 / set 12: zijpe'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #575 / set 12: mbigou'
# ------------
# 'Processing Record for index #576 / set 12: rio branco'
# ------------
# 'Processing Record for index #577 / set 12: tambura'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #578 / set 12: uvat'
# ------------
# 'Processing Record for index #579 / set 12: rosarito'
# ------------
# 'Processing Record for index #580 / set 12: saint anthony'
# ------------
# 'Processing Record for index #581 / set 12: soe'
# ------------
# 'Processing Record for index #582 / set 12: kuche'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #583 / set 12: mwinilunga'
# ------------
# 'Processing Record for index #584 / set 12: changping'
# ------------
# 'Processing Record for index #585 / set 12: iracoubo'
# ------------
# 'Processing Record for index #586 / set 12: itapua poty'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #587 / set 12: pontianak'
# ------------
# 'Processing Record for index #588 / set 12: manggar'
# ------------
# 'Processing Record for index #589 / set 12: lumberton'
# ------------
# 'Processing Record for index #590 / set 12: coihaique'
# ------------
# 'Processing Record for index #591 / set 12: marietta'
# ------------
# 'Processing Record for index #592 / set 12: truro'
# ------------
# 'Processing Record for index #593 / set 12: korsakov'
# ------------
# 'Processing Record for index #594 / set 12: daru'
# ------------
# 'Processing Record for index #595 / set 12: santa maria'
# ------------
# 'Processing Record for index #596 / set 12: kalabo'
# ------------
# 'Processing Record for index #597 / set 12: jardim'
# ------------
# 'Processing Record for index #598 / set 12: mizdah'
# ------------
# 'Processing Record for index #599 / set 12: nishihara'
# ------------
# 'Processing Record for index #600 / set 12: sokolo'
# ------------
# 'Processing Record for index #601 / set 13: sokolo'
# ------------
# 'Processing Record for index #602 / set 13: nakhon ratchasima'
# ------------
# 'Processing Record for index #603 / set 13: shingu'
# ------------
# 'Processing Record for index #604 / set 13: dolbeau'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #605 / set 13: siirt'
# ------------
# 'Processing Record for index #606 / set 13: hoquiam'
# ------------
# 'Processing Record for index #607 / set 13: stornoway'
# 'Missing field/result... skipping.'
# ------------
# 'Processing Record for index #608 / set 13: tateyama'
# ------------
# 'Processing Record for index #609 / set 13: kuala terengganu'
# ------------
# 'Processing Record for index #610 / set 13: konakovo'
# ------------
# 'Processing Record for index #611 / set 13: newcastle'
# ------------
# 'Processing Record for index #612 / set 13: guerrero negro'
# ------------
# 'Processing Record for index #613 / set 13: kenai'
# ------------
# 'Processing Record for index #614 / set 13: tanout'
# ------------
# 'Processing Record for index #615 / set 13: mana'
# ------------
# 'Processing Record for index #616 / set 13: caravelas'
# ------------
# 'Processing Record for index #617 / set 13: nizwa'
# ------------
# 'Processing Record for index #618 / set 13: iquitos'
# ------------
# 'Processing Record for index #619 / set 13: kununurra'
# ------------
# 'Processing Record for index #620 / set 13: sumbe'
# ------------
# 'Processing Record for index #621 / set 13: kostroma'
# ------------
# 'Processing Record for index #622 / set 13: iguape'
# ------------
# 'Processing Record for index #623 / set 13: karpogory'
# ------------
# 'Processing Record for index #624 / set 13: douglas'
# ------------
# 'Processing Record for index #625 / set 13: sivaki'
# ------------
# 'Processing Record for index #626 / set 13: newport'
# ------------
# 'Processing Record for index #627 / set 13: novoanninskiy'
# ------------
# 'Processing Record for index #628 / set 13: port-gentil'
# ------------

# %%
city_df
# Out:
#                   City Cloudiness Country   Date Humidity    Lat     Lng  \
# 0                 puri         20      ID     77      100  -7.54  112.45
# 1    guadalupe y calvo          0      MX  68.61       13  26.09 -106.96
# 2              rikitea         20      PF  79.77       97 -23.12 -134.97
# 3          barentsburg
# 4             saldanha          0      PT  46.38       59  41.42   -6.55
# 5           port hardy         20      CA   48.2       70   50.7 -127.42
# 6               mehamn         75      NO   30.2       68  71.03   27.85
# 7             khatanga         68      RU   6.24       80  71.98  102.47
# 8      bambous virieux         75      MU   82.4       74 -20.34   57.76
# 9       port elizabeth         75      US     59       22  39.31  -74.98
# 10      port macquarie         32      AU  84.99       88 -31.43  152.91
# 11          georgetown         40      GY   84.2       70    6.8  -58.16
# 12             jackson         40      US   71.6       35  35.61  -88.82
# 13          haileybury          1      CA   26.6       27  47.44  -79.64
# 14        puerto ayora          0      EC   84.2       74  -0.74  -90.35
# 15            bengkulu
# 16           cape town          0      ZA  66.99       82 -33.93   18.42
# 17               vardo          1      US   64.4       12  39.62  -77.74
# 18            tsihombe
# 19               vaini          0      IN  67.08       88  15.34   74.49
# 20              talaya          0      RU   28.4       79  55.79   84.89
# 21               bowen         92      AU  84.99       88 -20.01  148.25
# 22             urengoy         48      RU  18.03       81  65.96   78.37
# 23           mahebourg         75      MU   82.4       74 -20.41    57.7
# 24            karratha        100      AU  76.71       89 -20.74  116.85
# 25         san quintin          0      PH   74.1       57  17.54  120.52
# 26   sao joao da barra          0      BR     77       78 -21.64  -41.05
# 27       sioux lookout          5      CA   28.4       25   50.1  -91.92
# 28            tasiilaq         92      GL     23       73  65.61  -37.64
# 29              bargal
# ..                 ...        ...     ...    ...      ...    ...     ...
# 598          nishihara         75      JP  51.01       52  35.74  139.53
# 599             sokolo         76      ML  83.37       42  14.74   -6.12
# 600           vanavara         76      ML  83.37       42  14.74   -6.12
# 601  nakhon ratchasima         68      TH  87.01       56  14.97  102.09
# 602             shingu         20      JP  55.38      100  33.72  135.99
# 603            dolbeau
# 604              siirt         75      TR     50      100  37.93   41.94
# 605            hoquiam          1      US     63       58  46.98 -123.89
# 606          stornoway
# 607           tateyama         75      JP  51.01       42  36.66  137.31
# 608   kuala terengganu         75      MY   78.8       94   5.33  103.14
# 609           konakovo         12      RU  26.31       88  56.71   36.78
# 610          newcastle         20      ZA  51.78       88 -27.76   29.92
# 611     guerrero negro         12      MX  69.15       50  27.97 -114.04
# 612              kenai         90      US  46.99       88  60.55 -151.26
# 613             tanout         76      NE  79.05       15  14.97    8.88
# 614               mana          0      RS   46.4       69  43.52   20.24
# 615          caravelas         80      BR  82.47      100 -17.73  -39.27
# 616              nizwa          0      OM  57.09       85  22.93   57.53
# 617            iquitos         75      PE   42.8      319  -3.75  -73.25
# 618          kununurra          0      AU   80.6       78 -15.77  128.74
# 619              sumbe        100      AO   80.4      100  -11.2   13.84
# 620           kostroma         90      RU   33.8       97  57.77   40.93
# 621             iguape          0      BR  74.01      100  -24.7  -47.56
# 622          karpogory         56      RU  31.26       93     64   44.44
# 623            douglas          1      US   73.4       13  31.34 -109.55
# 624             sivaki         12      RU     21       60  52.63  126.75
# 625            newport         20      GB  46.99       87  51.59      -3
# 626      novoanninskiy         68      RU     32       93  50.53   42.67
# 627        port-gentil         20      GA     77       94  -0.72    8.78
#
#     Max Temp Wind Speed
# 0         77       2.24
# 1      68.61       2.71
# 2      79.77      13.67
# 3
# 4      46.38       7.85
# 5       48.2        4.7
# 6       30.2      23.04
# 7       6.24      10.87
# 8       82.4      10.29
# 9         59      14.99
# 10     84.99       3.36
# 11      84.2      11.41
# 12      71.6       6.93
# 13      26.6      11.41
# 14      84.2       9.17
# 15
# 16     66.99      13.87
# 17      64.4       3.36
# 18
# 19     67.08        1.7
# 20      28.4       4.47
# 21     84.99       5.82
# 22     18.03      14.67
# 23      82.4      10.29
# 24     76.71      31.79
# 25      74.1       4.16
# 26        77       2.24
# 27      28.4       8.05
# 28        23      40.26
# 29
# ..       ...        ...
# 598    51.01      13.87
# 599    83.37       2.15
# 600    83.37       2.15
# 601    87.01        8.3
# 602    55.38       5.39
# 603
# 604       50       6.93
# 605       63       3.15
# 606
# 607    51.01      10.29
# 608     78.8       1.12
# 609    26.31      11.21
# 610    51.78       2.59
# 611    69.15      13.11
# 612    46.99       9.17
# 613    79.05      12.44
# 614     46.4       2.24
# 615    82.47      13.67
# 616    57.09       2.93
# 617     42.8       3.36
# 618     80.6        4.7
# 619     80.4       5.84
# 620     33.8       8.95
# 621    74.01       9.98
# 622    31.26       4.83
# 623     73.4       5.82
# 624       21       4.72
# 625    46.99      17.22
# 626       32       1.01
# 627       77       1.12
#
# [628 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df.to_csv("WeatherDatabyCity.csv", index=False, header=True)

# %%
city_df = pd.read_csv("WeatherDatabyCity.csv")
city_df.fillna("")
city_df[["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"]].count()
# Out:
# City          628
# Cloudiness    576
# Country       575
# Date          576
# Humidity      576
# Lat           576
# Lng           576
# Max Temp      576
# Wind Speed    576
# dtype: int64

# %%
# city_df

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
date = datetime.datetime.today().strftime("%B %d %Y")
date = date.lstrip("0")

latitude = city_df["Lat"]
temperature = city_df["Max Temp"]
plt.scatter(latitude, temperature, facecolors="red", edgecolors="black")
plt.title(f"Max Temperature vs Latitude ({date})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")

plt.savefig("./Max Temperature_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
humidity = city_df["Humidity"]
plt.scatter(latitude, humidity, facecolors="yellow", edgecolors="black")
plt.title(f"Humidity vs Latitude ({date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

plt.savefig("./Humidity_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
cloudiness = city_df["Cloudiness"]
plt.scatter(latitude, cloudiness, facecolors="green", edgecolors="black")
plt.title(f"Cloudiness vs Latitude ({date})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

plt.savefig("./Cloudiness_vs_Latitude.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
wind_speed = city_df["Wind Speed"]
plt.scatter(latitude, wind_speed, facecolors="blue", edgecolors="black")
plt.title(f"Wind Speed vs Latitude ({date})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

plt.savefig("./Wind Speed_vs_Latitude.png")
plt.show()
